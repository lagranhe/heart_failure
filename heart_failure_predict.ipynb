# %% [markdown]
# ### Data analisys using Decision Tree Classifier, Logistic Regression, Random Forest Classifier and Neural Network.
# #### The purpose of this project is to predict heart failure  using basic ML models. Dataset - heart failure clinic data from https://www.kaggle.com/andrewmvd/heart-failure-clinical-data. After сhoosing the most accurate model will be creating UI for further convenient use

# %% [markdown]
# ### 1. Import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os
import matplotlib.pyplot as plt
import seaborn as sns
import pickle

from sklearn.metrics import classification_report
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score

from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from keras.models import Sequential 
from keras.layers import Dense

# %% [markdown]
# ### 2. Data preparation

# %%
os.getcwd()
# Out:
# '/content/drive/My Drive/Heart_failure'

# %%
from google.colab import drive
drive.mount('/content/drive')
os.chdir('/content/drive/My Drive/Heart_failure')
base_data = pd.read_csv("heart_failure_clinical_records.csv", delimiter = ",")
base_data.columns

cols = ["age", "anaemia", "creatinine_phosphokinase", "diabetes", "ejection_fraction", "high_blood_pressure", "platelets",
        "serum_creatinine", "serum_sodium", "sex", "smoking", "DEATH_EVENT"]
data = base_data[cols].copy()
# create copy of data without useless columns such as "time"
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
data.isnull().any()
# check data with null

# %%
corr = data.corr()
corr[abs(corr['DEATH_EVENT']) > 0.1]['DEATH_EVENT']

# %%
# get to dataframe most correlated data
cols = ["age", "ejection_fraction", "serum_creatinine", "serum_sodium", "DEATH_EVENT"]
data = base_data[cols].copy()

# %%
data.describe()
# Sex - Gender of patient Male = 1, Female =0
# Age - Age of patient
# Diabetes - 0 = No, 1 = Yes
# Anaemia - 0 = No, 1 = Yes
# High_blood_pressure - 0 = No, 1 = Yes
# Smoking - 0 = No, 1 = Yes
# DEATH_EVENT - 0 = No, 1 = Yes

# %%
print(data.head())

# %% [markdown]
# ### 4. Training model

# %%
y = data.iloc[:,4]
x = data.iloc[:,0:4] # prediction death_event
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
# 30% of dataset for tests

# %%
def model(X_train, y_train):
    
    forest = RandomForestClassifier (n_estimators=20, random_state=0)
    forest.fit(X_train,y_train)
    print("Random Forest: {0}".format(forest.score(X_train,y_train)))
    
    lreg = LogisticRegression(max_iter=10000)
    lreg.fit(X_train,y_train)
    print("Regresja logistyczna: {0}".format(lreg.score(X_train,y_train)))
  
    tree = DecisionTreeClassifier()
    tree.fit(X_train,y_train)
    print("Decision Tree: {0}".format(tree.score(X_train,y_train)))

    nnm = Sequential()
    nnm.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu', input_dim = 4))
    nnm.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(2, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    nnm.summary()
    nnm.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])

    nnm.fit(X_train, y_train, batch_size = 32, epochs = 200)
    
    return forest, lreg, tree, nnm

forest, lreg, tree, nnm = model(X_train,y_train)

# %%
y1_predict = forest.predict(X_test)
print("Random Forest {0}".format(accuracy_score(y_test, y1_predict)))

y2_predict = lreg.predict(X_test)
print("Logistic Regresion {0}".format(accuracy_score(y_test, y2_predict)))

y3_predict = tree.predict(X_test)
print("Decision Tree {0}".format(accuracy_score(y_test, y3_predict)))

y4_predict = nnm.predict(X_test)
y4_predict = (y4_predict > 0.5)
print("Neural network {0}".format(accuracy_score(y_test, y4_predict)))

# %%
print("Ocena modelu 1. Random Forest")
print(classification_report(y_test,y1_predict))

print("Ocena modelu 2. Regresja logistyczna")
print(classification_report(y_test,y2_predict))

print("Ocena modelu 3. Decision Tree")
print(classification_report(y_test,y3_predict))

print("Ocena modelu 4. Neural network")
print(classification_report(y_test,y4_predict))
# Out:
# Ocena modelu 1. Random Forest
#               precision    recall  f1-score   support
#
#            0       0.75      0.89      0.81        62
#            1       0.59      0.36      0.44        28
#
#     accuracy                           0.72        90
#    macro avg       0.67      0.62      0.63        90
# weighted avg       0.70      0.72      0.70        90
#
# Ocena modelu 2. Regresja logistyczna
#               precision    recall  f1-score   support
#
#            0       0.74      0.87      0.80        62
#            1       0.53      0.32      0.40        28
#
#     accuracy                           0.70        90
#    macro avg       0.63      0.60      0.60        90
# weighted avg       0.67      0.70      0.68        90
#
# Ocena modelu 3. Decision Tree
#               precision    recall  f1-score   support
#
#            0       0.80      0.76      0.78        62
#            1       0.52      0.57      0.54        28
#
#     accuracy                           0.70        90
#    macro avg       0.66      0.66      0.66        90
# weighted avg       0.71      0.70      0.70        90
#
# Ocena modelu 4. Neural network
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81        62
#            1       0.56      0.36      0.43        28
#
#     accuracy                           0.71        90
#    macro avg       0.65      0.61      0.62        90
# weighted avg       0.69      0.71      0.69        90

# %% [markdown]
# **The highest accuracy has Random Forest (0.72) and Neural Network (0.71), but most essential characteristic for heart failure prediction is precision of positive death_event (death of patient) has Random Forest model (0.59). Let's try to use all data for dataframe**

# %% [markdown]
# ### 5. Training model (all data)

# %%
cols = ["age", "anaemia", "creatinine_phosphokinase", "diabetes", "ejection_fraction", "high_blood_pressure", "platelets",
        "serum_creatinine", "serum_sodium", "sex", "smoking", "DEATH_EVENT"]
data = base_data[cols].copy()

y = data.iloc[:,11]
x = data.iloc[:,0:11] # prediction death_event
X_train, X_test, y_train, y_test = train_test_split(x, y, test_size = 0.3, random_state = 0)
# 30% of dataset for tests

def model(X_train, y_train):
    
    forest = RandomForestClassifier (n_estimators=20, random_state=0)
    forest.fit(X_train,y_train)
    print("Random Forest: {0}".format(forest.score(X_train,y_train)))
    
    lreg = LogisticRegression(max_iter=10000)
    lreg.fit(X_train,y_train)
    print("Regresja logistyczna: {0}".format(lreg.score(X_train,y_train)))
  
    tree = DecisionTreeClassifier()
    tree.fit(X_train,y_train)
    print("Decision Tree: {0}".format(tree.score(X_train,y_train)))

    nnm = Sequential()
    nnm.add(Dense(12, kernel_initializer = 'uniform', activation = 'relu', input_dim = 11))
    nnm.add(Dense(8, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(6, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(4, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(2, kernel_initializer = 'uniform', activation = 'relu'))
    nnm.add(Dense(1, kernel_initializer = 'uniform', activation = 'sigmoid'))
    nnm.summary()
    nnm.compile(optimizer = 'adam', loss = 'binary_crossentropy', metrics = ['accuracy'])
    nnm.fit(X_train, y_train, batch_size = 32, epochs = 200)
    
    return forest, lreg, tree, nnm

forest, lreg, tree, nnm = model(X_train,y_train)


y1_predict = forest.predict(X_test)
print("Random Forest {0}".format(accuracy_score(y_test, y1_predict)))

y2_predict = lreg.predict(X_test)
print("Logistic Regresion {0}".format(accuracy_score(y_test, y2_predict)))

y3_predict = tree.predict(X_test)
print("Decision Tree {0}".format(accuracy_score(y_test, y3_predict)))

y4_predict = nnm.predict(X_test)
y4_predict = (y4_predict > 0.5)
print("Neural network {0}".format(accuracy_score(y_test, y4_predict)))

print("Ocena modelu 1. Random Forest")
print(classification_report(y_test,y1_predict))

print("Ocena modelu 2. Regresja logistyczna")
print(classification_report(y_test,y2_predict))

print("Ocena modelu 3. Decision Tree")
print(classification_report(y_test,y3_predict))

print("Ocena modelu 4. Neural network")
print(classification_report(y_test,y4_predict))
# Out:
# Random Forest: 1.0
# Regresja logistyczna: 0.7751196172248804
# Decision Tree: 1.0
# Model: "sequential_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_144 (Dense)           (None, 12)                144
#
#  dense_145 (Dense)           (None, 8)                 104
#
#  dense_146 (Dense)           (None, 6)                 54
#
#  dense_147 (Dense)           (None, 4)                 28
#
#  dense_148 (Dense)           (None, 2)                 10
#
#  dense_149 (Dense)           (None, 1)                 3
#
# =================================================================
# Total params: 343
# Trainable params: 343
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 7/7 [==============================] - 1s 3ms/step - loss: 0.6920 - accuracy: 0.6746
# Epoch 2/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6884 - accuracy: 0.6746
# Epoch 3/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6818 - accuracy: 0.6746
# Epoch 4/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6682 - accuracy: 0.6746
# Epoch 5/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6475 - accuracy: 0.6746
# Epoch 6/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 7/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6354 - accuracy: 0.6746
# Epoch 8/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6336 - accuracy: 0.6746
# Epoch 9/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6341 - accuracy: 0.6746
# Epoch 10/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6344 - accuracy: 0.6746
# Epoch 11/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6335 - accuracy: 0.6746
# Epoch 12/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6356 - accuracy: 0.6746
# Epoch 13/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6343 - accuracy: 0.6746
# Epoch 14/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6338 - accuracy: 0.6746
# Epoch 15/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6333 - accuracy: 0.6746
# Epoch 16/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6338 - accuracy: 0.6746
# Epoch 17/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6338 - accuracy: 0.6746
# Epoch 18/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6340 - accuracy: 0.6746
# Epoch 19/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 20/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6746
# Epoch 21/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6342 - accuracy: 0.6746
# Epoch 22/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6341 - accuracy: 0.6746
# Epoch 23/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 24/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 25/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.6746
# Epoch 26/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6342 - accuracy: 0.6746
# Epoch 27/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 28/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 29/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6334 - accuracy: 0.6746
# Epoch 30/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.6746
# Epoch 31/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6338 - accuracy: 0.6746
# Epoch 32/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 33/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 34/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6333 - accuracy: 0.6746
# Epoch 35/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 36/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6339 - accuracy: 0.6746
# Epoch 37/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6336 - accuracy: 0.6746
# Epoch 38/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6337 - accuracy: 0.6746
# Epoch 39/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 40/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6327 - accuracy: 0.6746
# Epoch 41/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 42/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6355 - accuracy: 0.6746
# Epoch 43/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 44/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 45/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 46/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 47/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6339 - accuracy: 0.6746
# Epoch 48/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 49/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 50/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6347 - accuracy: 0.6746
# Epoch 51/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.6746
# Epoch 52/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 53/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 54/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 55/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 56/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6349 - accuracy: 0.6746
# Epoch 57/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 58/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 59/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6337 - accuracy: 0.6746
# Epoch 60/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 61/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6334 - accuracy: 0.6746
# Epoch 62/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6340 - accuracy: 0.6746
# Epoch 63/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 64/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6352 - accuracy: 0.6746
# Epoch 65/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 66/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 67/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6338 - accuracy: 0.6746
# Epoch 68/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 69/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 70/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 71/200
# 7/7 [==============================] - 0s 2ms/step - loss: 0.6341 - accuracy: 0.6746
# Epoch 72/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6335 - accuracy: 0.6746
# Epoch 73/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 74/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 75/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 76/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 77/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 78/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6329 - accuracy: 0.6746
# Epoch 79/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 80/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6346 - accuracy: 0.6746
# Epoch 81/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 82/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 83/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6327 - accuracy: 0.6746
# Epoch 84/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 85/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6328 - accuracy: 0.6746
# Epoch 86/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 87/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 88/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 89/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6327 - accuracy: 0.6746
# Epoch 90/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 91/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6327 - accuracy: 0.6746
# Epoch 92/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 93/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 94/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 95/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 96/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 97/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6335 - accuracy: 0.6746
# Epoch 98/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 99/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 100/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 101/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 102/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6331 - accuracy: 0.6746
# Epoch 103/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 104/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 105/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 106/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 107/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 108/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 109/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 110/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 111/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 112/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 113/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 114/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 115/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 116/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 117/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 118/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 119/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 120/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 121/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6325 - accuracy: 0.6746
# Epoch 122/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 123/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 124/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 125/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 126/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.6746
# Epoch 127/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 128/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 129/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 130/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 131/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 132/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 133/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6332 - accuracy: 0.6746
# Epoch 134/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 135/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 136/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6330 - accuracy: 0.6746
# Epoch 137/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 138/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 139/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 140/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.6746
# Epoch 141/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 142/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6324 - accuracy: 0.6746
# Epoch 143/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 144/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 145/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 146/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6317 - accuracy: 0.6746
# Epoch 147/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 148/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 149/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6326 - accuracy: 0.6746
# Epoch 150/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 151/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 152/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 153/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 154/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 155/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 156/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 157/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 158/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 159/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 160/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 161/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 162/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 163/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 164/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 165/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 166/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 167/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.6746
# Epoch 168/200
# 7/7 [==============================] - 0s 5ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 169/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6314 - accuracy: 0.6746
# Epoch 170/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 171/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 172/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 173/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 174/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 175/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6321 - accuracy: 0.6746
# Epoch 176/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 177/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 178/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 179/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.6746
# Epoch 180/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6315 - accuracy: 0.6746
# Epoch 181/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 182/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.6746
# Epoch 183/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 184/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 185/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.6746
# Epoch 186/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6313 - accuracy: 0.6746
# Epoch 187/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 188/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6317 - accuracy: 0.6746
# Epoch 189/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6314 - accuracy: 0.6746
# Epoch 190/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6319 - accuracy: 0.6746
# Epoch 191/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 192/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6320 - accuracy: 0.6746
# Epoch 193/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6314 - accuracy: 0.6746
# Epoch 194/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6323 - accuracy: 0.6746
# Epoch 195/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6312 - accuracy: 0.6746
# Epoch 196/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6318 - accuracy: 0.6746
# Epoch 197/200
# 7/7 [==============================] - 0s 6ms/step - loss: 0.6316 - accuracy: 0.6746
# Epoch 198/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6322 - accuracy: 0.6746
# Epoch 199/200
# 7/7 [==============================] - 0s 4ms/step - loss: 0.6312 - accuracy: 0.6746
# Epoch 200/200
# 7/7 [==============================] - 0s 3ms/step - loss: 0.6311 - accuracy: 0.6746
# Random Forest 0.7111111111111111
# Logistic Regresion 0.6888888888888889
# Decision Tree 0.6777777777777778
# Neural network 0.6888888888888889
# Ocena modelu 1. Random Forest
#               precision    recall  f1-score   support
#
#            0       0.75      0.87      0.81        62
#            1       0.56      0.36      0.43        28
#
#     accuracy                           0.71        90
#    macro avg       0.65      0.61      0.62        90
# weighted avg       0.69      0.71      0.69        90
#
# Ocena modelu 2. Regresja logistyczna
#               precision    recall  f1-score   support
#
#            0       0.73      0.87      0.79        62
#            1       0.50      0.29      0.36        28
#
#     accuracy                           0.69        90
#    macro avg       0.61      0.58      0.58        90
# weighted avg       0.66      0.69      0.66        90
#
# Ocena modelu 3. Decision Tree
#               precision    recall  f1-score   support
#
#            0       0.74      0.82      0.78        62
#            1       0.48      0.36      0.41        28
#
#     accuracy                           0.68        90
#    macro avg       0.61      0.59      0.59        90
# weighted avg       0.66      0.68      0.66        90
#
# Ocena modelu 4. Neural network
#               precision    recall  f1-score   support
#
#            0       0.69      1.00      0.82        62
#            1       0.00      0.00      0.00        28
#
#     accuracy                           0.69        90
#    macro avg       0.34      0.50      0.41        90
# weighted avg       0.47      0.69      0.56        90
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1308: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# **In dataframe with all data highest accuracy has Random Forest model, precision of positive death_event (death of patient) in Neural Network model is 0.**

# %% [markdown]
# ### 6. Model export

# %% [markdown]
# #### Best results of accuracy and precision has Random Forest model and model based on all data in dataframe will be exported.

# %%
filename = "heart_failure_model.sv"
pickle.dump(forest, open(filename,'wb'))
